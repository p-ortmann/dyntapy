# %% [markdown]
# # Introducing StaPy - (automatic) Static Traffic Assignment in Python

# %%
#importing modules from stapy

from stapy.network_data import get_from_ox_and_save, load_pickle
from stapy.assignment_methods import DUE
from stapy.od_matrix_generator import generate_od, generate_od_fixed
from stapy.visualization import plot_network, show_desire_lines

# %%
# First we download all the data from OpenStreetMap (here a driving network of the city Gent, Belgium) apply some filtering, estimate capacity and generate a routable graph
# The function returns two networkx Digraphs, one if some deleted network characteristics and the other with the network graph
# that we want to continue using.
g, deleted= get_from_ox_and_save('Gent', reload=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-25c4ded76a27> in <module>
#       2 # The function returns two networkx Digraphs, one if some deleted network characteristics and the other with the network graph
#       3 # that we want to continue using.
# ----> 4 g, deleted= get_from_ox_and_save('Gent', reload=True)
#
# C:\Workdir\Programs\research\Python TrafficToolBox\stapy\network_data.py in get_from_ox_and_save(name, plot_deleted, reload)
#      53             nx.write_gpickle(g, file_path + '_pure_ox')
#      54     else:
# ---> 55         log('Starting to load from OSM')
#      56         g = ox.graph_from_place(name, network_type='drive')
#      57         log('Finished downloading')
#
# C:\Workdir\Programs\research\Python TrafficToolBox\stapy\utilities.py in log(message, level, print)
#      83     """
#      84     if level is None:
# ...

# %%
# We now show some elements of the graph that are present in the osm dataset but could not be incorporated into the
# routable graph as they would not form one connected component with the rest of the network. This is a necessary condition for street
# networks and required for our shortest path algorithms to function properly. If one were interested in using StaPy for serious analysis
# manual checks would be required to make sure that none of the points that are being removed serve some crucial network function.
plot_network(deleted, mode='deleted elements', notebook=True)

# %%
# Note that you can hover over the edges and nodes of the network to see some more information, a left-hand click brings
# you to the corresponding entry in the OSM GUI.
# Node and Edge tap tools need to be switched between manually and can be selected just underneath the canvas.

# %%
#For now traffic demand is being generated randomly, here we pick 20 random od pairs in the network and load some traffic.
#In the future this will be replaced by a coarse demand generator based on OpenStreetMap data (see accompanying thesis text in the docs).


rand_od = generate_od_fixed(g.number_of_nodes(), number_of_od_values=20 )
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1059">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d501eb63-f8fd-496c-953b-7cd547009602" data-root-id="1001"></div>

# %%
#desire lines illustrate the randomly generated demand pattern in the network

show_desire_lines(g, rand_od, notebook=True)

# %%
#We're now able to start a traffic assignment based on Dial's algorithm B. The networkx Digraph g is being used to store
# the calculated flows and travel times.

DUE(g, od_matrix=rand_od, method='dial_b')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1195">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="0887c62f-bf50-4337-a1f4-ea09aadc9a2a" data-root-id="1137"></div>

# %%
# we can now show the results on the canvas
plot_network(g, notebook=True)
# Out:
# caling msa
